# %%
# Dependencies
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import scipy.stats as stats
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect

# %%
# Create SQL engine
engine = create_engine('postgresql://********:**********@localhost:5432/sql-challenge')
connection = engine.connect()

# %%
# Create inspector and find table names
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['employees', 'salaries', 'dept_emp', 'departments', 'titles', 'dept_manager']

# %%
# Read the tables
employees_db = pd.read_sql("SELECT * FROM employees", connection)
salaries_db = pd.read_sql("SELECT * FROM salaries", connection)
title_db = pd.read_sql("SELECT * FROM titles", connection)

# %%
# Show the table for salaries
salaries_db
# Out:
#         emp_no  salary
# 0        10001   60117
# 1        10002   65828
# 2        10003   40006
# 3        10004   40054
# 4        10005   78228
# ...        ...     ...
# 300019  499995   40000
# 300020  499996   58058
# 300021  499997   49597
# 300022  499998   40000
# 300023  499999   63707
#
# [300024 rows x 2 columns]

# %%
# Crate a histogram of salary ranges
plt.hist(salaries_db['salary'])
plt.xlabel("Salary")
plt.ylabel("Number of Employees")
plt.title("Salary Ranges")
plt.show()

# %%
#Create a bar chart of average salary per title
# Query the data
emp_title = pd.read_sql("SELECT * FROM employees INNER JOIN titles ON employees.emp_title = titles.title_id", connection)
emp_title
# Out:
#         emp_no emp_title  birth_date   first_name  last_name sex   hire_date  \
# 0       473302     s0001  1953-07-25     Hideyuki   Zallocco   M  1990-04-28
# 1       475053     e0002  1954-11-18        Byong  Delgrande   F  1991-09-07
# 2        57444     e0002  1958-01-30        Berry       Babb   F  1992-03-21
# 3       421786     s0001  1957-09-28        Xiong   Verhoeff   M  1987-11-26
# 4       282238     e0003  1952-10-28   Abdelkader    Baumann   F  1991-01-18
# ...        ...       ...         ...          ...        ...  ..         ...
# 300019  464231     s0001  1958-08-14  Constantino    Eastman   M  1988-10-28
# 300020  255832     e0002  1955-05-08       Yuping     Dayang   F  1995-02-26
# 300021   76671     s0001  1959-06-09       Ortrud   Plessier   M  1988-02-24
# 300022  264920     s0001  1959-09-22        Percy   Samarati   F  1994-09-08
# 300023  464503     s0002  1964-05-31       Arvind  Slobodova   M  1987-11-23
#
#        title_id           titles
# ...

# %%
emp_salary = pd.read_sql("SELECT * FROM employees INNER JOIN salaries ON employees.emp_no = salaries.emp_no", connection)
emp_salary
# Out:
#         emp_no emp_title  birth_date first_name    last_name sex   hire_date  \
# 0        10005     s0001  1955-01-21    Kyoichi     Maliniak   M  1989-09-12
# 1        10010     e0002  1963-06-01  Duangkaew     Piveteau   F  1989-08-24
# 2        10011     s0001  1953-11-07       Mary        Sluis   F  1990-01-22
# 3        10013     s0002  1963-06-07  Eberhardt       Terkki   M  1985-10-20
# 4        10017     s0001  1958-07-06  Cristinel    Bouloucos   F  1993-08-03
# ...        ...       ...         ...        ...          ...  ..         ...
# 300019  499948     e0002  1953-05-24   Cordelia    Paludetto   M  1993-01-28
# 300020  499972     e0003  1957-07-25     Katsuo       Leuchs   F  1989-11-23
# 300021  499985     s0001  1964-12-26       Gila  Lukaszewicz   M  1997-02-11
# 300022  499987     s0001  1961-09-05      Rimli       Dusink   F  1998-09-20
# 300023  499998     s0001  1956-09-05   Patricia      Breugel   M  1993-10-13
#
#         emp_no  salary
# ...

# %%
# merge the tables
sal_title = pd.merge(emp_title, emp_salary, how='inner', on= "first_name")
sal_title
# Out:
#           emp_no_x emp_title_x birth_date_x first_name last_name_x sex_x  \
# 0           473302       s0001   1953-07-25   Hideyuki    Zallocco     M
# 1           473302       s0001   1953-07-25   Hideyuki    Zallocco     M
# 2           473302       s0001   1953-07-25   Hideyuki    Zallocco     M
# 3           473302       s0001   1953-07-25   Hideyuki    Zallocco     M
# 4           473302       s0001   1953-07-25   Hideyuki    Zallocco     M
# ...            ...         ...          ...        ...         ...   ...
# 70886655    466340       s0002   1963-11-25   Radoslaw      Hebden     F
# 70886656    466340       s0002   1963-11-25   Radoslaw      Hebden     F
# 70886657    466340       s0002   1963-11-25   Radoslaw      Hebden     F
# 70886658    466340       s0002   1963-11-25   Radoslaw      Hebden     F
# 70886659    499942       e0004   1963-01-10      April    Foolsday     F
#
#          hire_date_x title_id            titles  emp_no_y emp_title_y  \
# ...

# %%
# Create the bar chart
avg_sal_title = sal_title.groupby(["titles"]).mean()["salary"]
avg_sal_title
# Out:
# titles
# Assistant Engineer    52956.058292
# Engineer              52955.056735
# Manager               52805.871254
# Senior Engineer       52946.278697
# Senior Staff          52991.103366
# Staff                 52995.753323
# Technique Leader      52935.373896
# Name: salary, dtype: float64

# %%
avg_sal_title.plot(kind="bar", facecolor="blue")
# Out:
# <AxesSubplot:xlabel='titles'>

# %%
#emp_no_499942 = employees_db["emp_no"] == 499942
emp_no_499942 = employees_db.loc[employees_db["emp_no"] == 499942, :]
emp_no_499942.head()
# Out:
#         emp_no emp_title  birth_date first_name last_name sex   hire_date
# 168736  499942     e0004  1963-01-10      April  Foolsday   F  1997-02-10
